# %% [markdown]
# # Revocar rol de Data Engineers y Data_Analysts

# %%
# %sql
-- CATALOGO
REVOKE ALL PRIVILEGES ON CATALOG formula1 FROM `Data_Engineers`;

-- PERMISOS ESQUEMAS
REVOKE CREATE, USE SCHEMA ON SCHEMA  formula1.bronze FROM `Data_Engineers`;
REVOKE CREATE, USE SCHEMA ON SCHEMA  formula1.silver FROM `Data_Engineers`;
REVOKE CREATE, USE SCHEMA ON SCHEMA  formula1.golden FROM `Data_Engineers`;

-- PERMISOS TABLAS DE Bronze, Silver, Gold
REVOKE SELECT ON TABLE formula1.bronze.circuits FROM `Data_Engineers`;
REVOKE SELECT ON TABLE formula1.bronze.constructors FROM `Data_Engineers`;
REVOKE SELECT ON TABLE formula1.bronze.drivers FROM `Data_Engineers`;
REVOKE SELECT ON TABLE formula1.bronze.races FROM `Data_Engineers`;
REVOKE SELECT ON TABLE formula1.bronze.results FROM `Data_Engineers`;
REVOKE SELECT ON TABLE formula1.bronze.sprints FROM `Data_Engineers`;


REVOKE SELECT ON TABLE formula1.silver.circuits FROM `Data_Engineers`;
REVOKE SELECT ON TABLE formula1.silver.constructors FROM `Data_Engineers`;
REVOKE SELECT ON TABLE formula1.silver.drivers FROM `Data_Engineers`;
REVOKE SELECT ON TABLE formula1.silver.races FROM `Data_Engineers`;
REVOKE SELECT ON TABLE formula1.silver.results FROM `Data_Engineers`;
REVOKE SELECT ON TABLE formula1.silver.sprints FROM `Data_Engineers`;

REVOKE SELECT ON TABLE formula1.silver.dim_constructors FROM `Data_Engineers`;
REVOKE SELECT ON TABLE formula1.silver.dim_drivers FROM `Data_Engineers`;
REVOKE SELECT ON TABLE formula1.silver.dim_races FROM `Data_Engineers`;
REVOKE SELECT ON TABLE formula1.silver.fact_session_results FROM `Data_Engineers`;
REVOKE SELECT ON TABLE formula1.silver.ref_nationality_region FROM `Data_Engineers`;
REVOKE SELECT ON TABLE formula1.silver.v_constructor_standing FROM `Data_Engineers`;
REVOKE SELECT ON TABLE formula1.silver.v_driver_standing FROM `Data_Engineers`;


-- CATALOGO
REVOKE ALL PRIVILEGES ON CATALOG formula1 FROM `Data_Analysts`;

-- PERMISOS ESQUEMAS
REVOKE CREATE, USE SCHEMA ON SCHEMA  formula1.silver FROM `Data_Analysts`;
REVOKE CREATE, USE SCHEMA ON SCHEMA  formula1.golden FROM `Data_Analysts`;

-- PERMISOS TABLAS DE Silver, Gold
REVOKE SELECT ON TABLE formula1.silver.circuits FROM `Data_Analysts`;
REVOKE SELECT ON TABLE formula1.silver.constructors FROM `Data_Analysts`;
REVOKE SELECT ON TABLE formula1.silver.drivers FROM `Data_Analysts`;
REVOKE SELECT ON TABLE formula1.silver.races FROM `Data_Analysts`;
REVOKE SELECT ON TABLE formula1.silver.results FROM `Data_Analysts`;
REVOKE SELECT ON TABLE formula1.silver.sprints FROM `Data_Analysts`;

REVOKE SELECT ON TABLE formula1.silver.dim_constructors FROM `Data_Analysts`;
REVOKE SELECT ON TABLE formula1.silver.dim_drivers FROM `Data_Analysts`;
REVOKE SELECT ON TABLE formula1.silver.dim_races FROM `Data_Analysts`;
REVOKE SELECT ON TABLE formula1.silver.fact_session_results FROM `Data_Analysts`;
REVOKE SELECT ON TABLE formula1.silver.ref_nationality_region FROM `Data_Analysts`;
REVOKE SELECT ON TABLE formula1.silver.v_constructor_standing FROM `Data_Analysts`;
REVOKE SELECT ON TABLE formula1.silver.v_driver_standing FROM `Data_Analysts`;

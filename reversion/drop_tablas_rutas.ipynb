# %% [markdown]
# # External Locations

# %%
# %sql
--DROP EXTERNAL LOCATION IF EXISTS `eberdatabrickscoursedl_formula1` FORCE;
--DROP EXTERNAL LOCATION IF EXISTS `eberdatabrickscoursedl` FORCE;
--DROP EXTERNAL LOCATION IF EXISTS `databricks_course_ws_prd` FORCE;

# %% [markdown]
# # Tables and Schema

# %%
# Drop tables and views related to F1_Project_V2

#spark.sql("DROP TABLE IF EXISTS f1_project_v2.race_results")
#spark.sql("DROP TABLE IF EXISTS f1_project_v2.drivers")
#spark.sql("DROP TABLE IF EXISTS f1_project_v2.circuits")
#spark.sql("DROP TABLE IF EXISTS f1_project_v2.constructors")
#spark.sql("DROP TABLE IF EXISTS f1_project_v2.races")
#spark.sql("DROP TABLE IF EXISTS f1_project_v2.pit_stops")
#spark.sql("DROP TABLE IF EXISTS f1_project_v2.qualifying")
#spark.sql("DROP TABLE IF EXISTS f1_project_v2.lap_times")
#spark.sql("DROP TABLE IF EXISTS f1_project_v2.status")
#spark.sql("DROP VIEW IF EXISTS f1_project_v2.driver_standings")
#spark.sql("DROP VIEW IF EXISTS f1_project_v2.constructor_standings")

# Drop schema and all associated objects
#spark.sql("DROP SCHEMA IF EXISTS f1_project_v2 CASCADE")

# %% [markdown]
# # Rutas Fisicas

# %%
# %python
#dbutils.fs.rm(f"abfss://bronze@eberdatabrickscoursedl.dfs.core.windows.net/",True)
#dbutils.fs.rm(f"abfss://silver@eberdatabrickscoursedl.dfs.core.windows.net/",True)
#dbutils.fs.rm(f"abfss://golden@eberdatabrickscoursedl.dfs.core.windows.net/",True)
#dbutils.fs.rm(f"abfss://landing@eberdatabrickscoursedl.dfs.core.windows.net/",True)

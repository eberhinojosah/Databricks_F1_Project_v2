# %%
# Unity Catalog Object Name
catalog_name = 'formula1'
bronze_schema = 'bronze'
silver_shema = 'silver'
gold_schema = 'gold'

# %%
landing_folder_path  = "abfss://formula1@eberdatabrickscoursedl.dfs.core.windows.net/landing"
